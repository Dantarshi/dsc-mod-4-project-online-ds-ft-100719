# %% [markdown]
# # Introduction

# %% [markdown]
# ## Predicting the top 5 zip codes in El Paso, Texas to invest in

# %%
#Importing Libraries
#for math and data structure
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
#for modeling
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose as sd
import itertools
#for visualizations
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import seaborn as sns
sns.set_style('darkgrid')

# %%
zillow_data = pd.read_csv("zillow_data.csv")
zillow_data.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df = zillow_data.groupby('State').get_group('TX')
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 4     93144       79936   El Paso    TX            El Paso    El Paso
# 5     91733       77084   Houston    TX            Houston     Harris
# 8     91940       77449      Katy    TX            Houston     Harris
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
# 5         6   95000.0   95200.0   95400.0  ...   157900   158700   160200
# 8         9   95400.0   95600.0   95800.0  ...   166800   167400   168400
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 4   120300   120300   120300   120300   120500   121000   121500
# 5   161900   162800   162800   162800   162900   163500   164300
# 8   169600   170900   172300   173300   174200   175400   176200
#
# [5 rows x 272 columns]

# %% [markdown]
# # Reshape from Wide to Long Format

# %%
def melt_data(df): 
    melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName', 'SizeRank'], var_name='Month', value_name='MeanValue')
    
    melted['Month'] = pd.to_datetime(melted['Month'], format='%Y-%m')
    melted = melted.dropna(subset=['MeanValue'])
    return melted

# %%
df = melt_data(zillow_data)
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank      Month  MeanValue
# 0         1 1996-04-01   334200.0
# 1         2 1996-04-01   235700.0
# 2         3 1996-04-01   210400.0
# 3         4 1996-04-01   498100.0
# 4         5 1996-04-01    77300.0

# %%
def make_datetimeindex(df,col_to_make_index = 'Month',drop=False,verbose=True):

    df[col_to_make_index] = pd.to_datetime(df[col_to_make_index],errors='coerce')
    df = df.set_index('Month',drop=drop)
    
    if verbose:
        display(df.index)
    return df

# %%
#putting time series to the dataset
df = make_datetimeindex(df)
# Out:
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01',
#                ...
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Month', length=3744704, freq=None)

# %%
df.head()
# Out:
#             RegionID  RegionName      City State              Metro  \
# Month
# 1996-04-01     84654       60657   Chicago    IL            Chicago
# 1996-04-01     90668       75070  McKinney    TX  Dallas-Fort Worth
# 1996-04-01     91982       77494      Katy    TX            Houston
# 1996-04-01     84616       60614   Chicago    IL            Chicago
# 1996-04-01     93144       79936   El Paso    TX            El Paso
#
#            CountyName  SizeRank      Month  MeanValue
# Month
# 1996-04-01       Cook         1 1996-04-01   334200.0
# 1996-04-01     Collin         2 1996-04-01   235700.0
# 1996-04-01     Harris         3 1996-04-01   210400.0
# 1996-04-01       Cook         4 1996-04-01   498100.0
# 1996-04-01    El Paso         5 1996-04-01    77300.0

# %%
df = df.rename({'Month':'MonthOrig'},axis=1)
df.head()
# Out:
#             RegionID  RegionName      City State              Metro  \
# Month
# 1996-04-01     84654       60657   Chicago    IL            Chicago
# 1996-04-01     90668       75070  McKinney    TX  Dallas-Fort Worth
# 1996-04-01     91982       77494      Katy    TX            Houston
# 1996-04-01     84616       60614   Chicago    IL            Chicago
# 1996-04-01     93144       79936   El Paso    TX            El Paso
#
#            CountyName  SizeRank  MonthOrig  MeanValue
# Month
# 1996-04-01       Cook         1 1996-04-01   334200.0
# 1996-04-01     Collin         2 1996-04-01   235700.0
# 1996-04-01     Harris         3 1996-04-01   210400.0
# 1996-04-01       Cook         4 1996-04-01   498100.0
# 1996-04-01    El Paso         5 1996-04-01    77300.0

# %%
df_city =  df.groupby('City').get_group('El Paso')
df_county = df.groupby('CountyName').get_group('El Paso')

display(df_city.head(),df_city.index,df_county.head())
# Out:
#             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# Month
# 1996-04-01     93144       79936  El Paso    TX  El Paso    El Paso         5
# 1996-04-01     93123       79912  El Paso    TX  El Paso    El Paso        26
# 1996-04-01     93146       79938  El Paso    TX  El Paso    El Paso       179
# 1996-04-01     93133       79924  El Paso    TX  El Paso    El Paso       491
# 1996-04-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#
#             MonthOrig  MeanValue
# Month
# 1996-04-01 1996-04-01    77300.0
# 1996-04-01 1996-04-01   119700.0
# 1996-04-01 1996-04-01    98400.0
# 1996-04-01 1996-04-01    61700.0
# 1996-04-01 1996-04-01    58900.0
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01',
#                ...
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Month', length=4828, freq=None)
#             RegionID  RegionName              City State             Metro  \
# Month
# 1996-04-01     93144       79936           El Paso    TX           El Paso
# 1996-04-01     93123       79912           El Paso    TX           El Paso
# 1996-04-01     93146       79938           El Paso    TX           El Paso
# 1996-04-01     93133       79924           El Paso    TX           El Paso
# 1996-04-01     93596       80918  Colorado Springs    CO  Colorado Springs
#
#            CountyName  SizeRank  MonthOrig  MeanValue
# Month
# 1996-04-01    El Paso         5 1996-04-01    77300.0
# 1996-04-01    El Paso        26 1996-04-01   119700.0
# 1996-04-01    El Paso       179 1996-04-01    98400.0
# 1996-04-01    El Paso       491 1996-04-01    61700.0
# 1996-04-01    El Paso       791 1996-04-01   128200.0

# %%
# checking number of zipcode in El paso
print(f"[i] There are {df_city['RegionName'].nunique()} zipcodes in El Paso")
display(df_city.head())
df_city.index
# Out:
# [i] There are 19 zipcodes in El Paso
#             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# Month
# 1996-04-01     93144       79936  El Paso    TX  El Paso    El Paso         5
# 1996-04-01     93123       79912  El Paso    TX  El Paso    El Paso        26
# 1996-04-01     93146       79938  El Paso    TX  El Paso    El Paso       179
# 1996-04-01     93133       79924  El Paso    TX  El Paso    El Paso       491
# 1996-04-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#
#             MonthOrig  MeanValue
# Month
# 1996-04-01 1996-04-01    77300.0
# 1996-04-01 1996-04-01   119700.0
# 1996-04-01 1996-04-01    98400.0
# 1996-04-01 1996-04-01    61700.0
# 1996-04-01 1996-04-01    58900.0
# DatetimeIndex(['1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01', '1996-04-01', '1996-04-01',
#                '1996-04-01', '1996-04-01',
#                ...
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01', '2018-04-01', '2018-04-01',
#                '2018-04-01', '2018-04-01'],
#               dtype='datetime64[ns]', name='Month', length=4828, freq=None)

# %% [markdown]
# Make El Paso ( dict of Zipcodes dfs)

# %% [markdown]
# # EDA and Visualization

# %%
El_P = {}
for zipcode in df_city['RegionName'].unique():
    temp = df_city.groupby("RegionName").get_group(zipcode)
    El_P[zipcode]=temp.resample('MS').asfreq()
El_P
# Out:
# {79936:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  1996-05-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  1996-06-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  1996-07-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  1996-08-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  2018-01-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  2018-02-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  2018-03-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#  2018-04-01     93144       79936  El Paso    TX  El Paso    El Paso         5
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    77300.0
#  1996-05-01 1996-05-01    77300.0
#  1996-06-01 1996-06-01    77300.0
#  1996-07-01 1996-07-01    77300.0
#  1996-08-01 1996-08-01    77400.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   120300.0
#  2018-01-01 2018-01-01   120300.0
#  2018-02-01 2018-02-01   120500.0
#  2018-03-01 2018-03-01   121000.0
#  2018-04-01 2018-04-01   121500.0
#
#  [265 rows x 9 columns],
#  79912:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  1996-05-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  1996-06-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  1996-07-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  1996-08-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  2018-01-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  2018-02-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  2018-03-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#  2018-04-01     93123       79912  El Paso    TX  El Paso    El Paso        26
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01   119700.0
#  1996-05-01 1996-05-01   119700.0
#  1996-06-01 1996-06-01   119800.0
#  1996-07-01 1996-07-01   119900.0
#  1996-08-01 1996-08-01   120000.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   184700.0
#  2018-01-01 2018-01-01   184800.0
#  2018-02-01 2018-02-01   185900.0
#  2018-03-01 2018-03-01   187200.0
#  2018-04-01 2018-04-01   188100.0
#
#  [265 rows x 9 columns],
#  79938:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  1996-05-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  1996-06-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  1996-07-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  1996-08-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  2018-01-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  2018-02-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  2018-03-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#  2018-04-01     93146       79938  El Paso    TX  El Paso    El Paso       179
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    98400.0
#  1996-05-01 1996-05-01    97700.0
#  1996-06-01 1996-06-01    97200.0
#  1996-07-01 1996-07-01    96700.0
#  1996-08-01 1996-08-01    96300.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   143800.0
#  2018-01-01 2018-01-01   143700.0
#  2018-02-01 2018-02-01   143900.0
#  2018-03-01 2018-03-01   144400.0
#  2018-04-01 2018-04-01   144600.0
#
#  [265 rows x 9 columns],
#  79924:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  1996-05-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  1996-06-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  1996-07-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  1996-08-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  2018-01-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  2018-02-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  2018-03-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#  2018-04-01     93133       79924  El Paso    TX  El Paso    El Paso       491
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    61700.0
#  1996-05-01 1996-05-01    61600.0
#  1996-06-01 1996-06-01    61500.0
#  1996-07-01 1996-07-01    61500.0
#  1996-08-01 1996-08-01    61500.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    93600.0
#  2018-01-01 2018-01-01    93800.0
#  2018-02-01 2018-02-01    94400.0
#  2018-03-01 2018-03-01    94900.0
#  2018-04-01 2018-04-01    94800.0
#
#  [265 rows x 9 columns],
#  79907:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  1996-05-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  1996-06-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  1996-07-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  1996-08-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  2018-01-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  2018-02-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  2018-03-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#  2018-04-01     93119       79907  El Paso    TX  El Paso    El Paso      1136
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    58900.0
#  1996-05-01 1996-05-01    58800.0
#  1996-06-01 1996-06-01    58800.0
#  1996-07-01 1996-07-01    58800.0
#  1996-08-01 1996-08-01    58700.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    93700.0
#  2018-01-01 2018-01-01    93800.0
#  2018-02-01 2018-02-01    94000.0
#  2018-03-01 2018-03-01    94100.0
#  2018-04-01 2018-04-01    93900.0
#
#  [265 rows x 9 columns],
#  79925:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  1996-05-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  1996-06-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  1996-07-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  1996-08-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  2018-01-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  2018-02-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  2018-03-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#  2018-04-01     93134       79925  El Paso    TX  El Paso    El Paso      1636
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    81600.0
#  1996-05-01 1996-05-01    81600.0
#  1996-06-01 1996-06-01    81700.0
#  1996-07-01 1996-07-01    81800.0
#  1996-08-01 1996-08-01    81900.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   126900.0
#  2018-01-01 2018-01-01   127400.0
#  2018-02-01 2018-02-01   128300.0
#  2018-03-01 2018-03-01   129900.0
#  2018-04-01 2018-04-01   131200.0
#
#  [265 rows x 9 columns],
#  79915:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  1996-05-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  1996-06-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  1996-07-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  1996-08-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  2018-01-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  2018-02-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  2018-03-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#  2018-04-01     93126       79915  El Paso    TX  El Paso    El Paso      2711
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    57600.0
#  1996-05-01 1996-05-01    57600.0
#  1996-06-01 1996-06-01    57700.0
#  1996-07-01 1996-07-01    57800.0
#  1996-08-01 1996-08-01    57800.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    85600.0
#  2018-01-01 2018-01-01    84900.0
#  2018-02-01 2018-02-01    84900.0
#  2018-03-01 2018-03-01    85500.0
#  2018-04-01 2018-04-01    85700.0
#
#  [265 rows x 9 columns],
#  79904:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  1996-05-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  1996-06-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  1996-07-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  1996-08-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  2018-01-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  2018-02-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  2018-03-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#  2018-04-01     93116       79904  El Paso    TX  El Paso    El Paso      3179
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    60100.0
#  1996-05-01 1996-05-01    60100.0
#  1996-06-01 1996-06-01    60000.0
#  1996-07-01 1996-07-01    60000.0
#  1996-08-01 1996-08-01    60000.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    93800.0
#  2018-01-01 2018-01-01    94000.0
#  2018-02-01 2018-02-01    94200.0
#  2018-03-01 2018-03-01    94100.0
#  2018-04-01 2018-04-01    93900.0
#
#  [265 rows x 9 columns],
#  79902:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  1996-05-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  1996-06-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  1996-07-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  1996-08-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  2018-01-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  2018-02-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  2018-03-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#  2018-04-01     93114       79902  El Paso    TX  El Paso    El Paso      4328
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01   101900.0
#  1996-05-01 1996-05-01   101700.0
#  1996-06-01 1996-06-01   101600.0
#  1996-07-01 1996-07-01   101400.0
#  1996-08-01 1996-08-01   101300.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   189500.0
#  2018-01-01 2018-01-01   190100.0
#  2018-02-01 2018-02-01   191500.0
#  2018-03-01 2018-03-01   192000.0
#  2018-04-01 2018-04-01   191200.0
#
#  [265 rows x 9 columns],
#  79934:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  1996-05-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  1996-06-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  1996-07-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  1996-08-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  2018-01-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  2018-02-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  2018-03-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#  2018-04-01     93142       79934  El Paso    TX  El Paso    El Paso      4407
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    93800.0
#  1996-05-01 1996-05-01    93400.0
#  1996-06-01 1996-06-01    93100.0
#  1996-07-01 1996-07-01    92800.0
#  1996-08-01 1996-08-01    92500.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   142700.0
#  2018-01-01 2018-01-01   142600.0
#  2018-02-01 2018-02-01   142700.0
#  2018-03-01 2018-03-01   142700.0
#  2018-04-01 2018-04-01   142300.0
#
#  [265 rows x 9 columns],
#  79930:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  1996-05-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  1996-06-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  1996-07-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  1996-08-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  2018-01-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  2018-02-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  2018-03-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#  2018-04-01     93139       79930  El Paso    TX  El Paso    El Paso      4422
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    58300.0
#  1996-05-01 1996-05-01    58400.0
#  1996-06-01 1996-06-01    58400.0
#  1996-07-01 1996-07-01    58400.0
#  1996-08-01 1996-08-01    58400.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    91900.0
#  2018-01-01 2018-01-01    92100.0
#  2018-02-01 2018-02-01    92400.0
#  2018-03-01 2018-03-01    92600.0
#  2018-04-01 2018-04-01    92500.0
#
#  [265 rows x 9 columns],
#  79932:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  1996-05-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  1996-06-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  1996-07-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  1996-08-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  2018-01-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  2018-02-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  2018-03-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#  2018-04-01     93141       79932  El Paso    TX  El Paso    El Paso      4705
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01   112400.0
#  1996-05-01 1996-05-01   112000.0
#  1996-06-01 1996-06-01   111700.0
#  1996-07-01 1996-07-01   111300.0
#  1996-08-01 1996-08-01   111000.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   175100.0
#  2018-01-01 2018-01-01   175800.0
#  2018-02-01 2018-02-01   176100.0
#  2018-03-01 2018-03-01   176100.0
#  2018-04-01 2018-04-01   176000.0
#
#  [265 rows x 9 columns],
#  79905:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  1996-05-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  1996-06-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  1996-07-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  1996-08-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  2018-01-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  2018-02-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  2018-03-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#  2018-04-01     93117       79905  El Paso    TX  El Paso    El Paso      5384
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    54400.0
#  1996-05-01 1996-05-01    54200.0
#  1996-06-01 1996-06-01    54100.0
#  1996-07-01 1996-07-01    54000.0
#  1996-08-01 1996-08-01    53900.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    78300.0
#  2018-01-01 2018-01-01    77600.0
#  2018-02-01 2018-02-01    77400.0
#  2018-03-01 2018-03-01    77800.0
#  2018-04-01 2018-04-01    78000.0
#
#  [265 rows x 9 columns],
#  79903:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  1996-05-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  1996-06-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  1996-07-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  1996-08-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  2018-01-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  2018-02-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  2018-03-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#  2018-04-01     93115       79903  El Paso    TX  El Paso    El Paso      6406
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    58600.0
#  1996-05-01 1996-05-01    58500.0
#  1996-06-01 1996-06-01    58500.0
#  1996-07-01 1996-07-01    58500.0
#  1996-08-01 1996-08-01    58600.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    93700.0
#  2018-01-01 2018-01-01    93800.0
#  2018-02-01 2018-02-01    94400.0
#  2018-03-01 2018-03-01    95200.0
#  2018-04-01 2018-04-01    95600.0
#
#  [265 rows x 9 columns],
#  79935:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  1996-05-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  1996-06-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  1996-07-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  1996-08-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  2018-01-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  2018-02-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  2018-03-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#  2018-04-01     93143       79935  El Paso    TX  El Paso    El Paso      6490
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    90700.0
#  1996-05-01 1996-05-01    90600.0
#  1996-06-01 1996-06-01    90600.0
#  1996-07-01 1996-07-01    90600.0
#  1996-08-01 1996-08-01    90700.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   141500.0
#  2018-01-01 2018-01-01   141100.0
#  2018-02-01 2018-02-01   141100.0
#  2018-03-01 2018-03-01   141700.0
#  2018-04-01 2018-04-01   142400.0
#
#  [265 rows x 9 columns],
#  79901:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  1996-05-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  1996-06-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  1996-07-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  1996-08-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  2018-01-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  2018-02-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  2018-03-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#  2018-04-01     93113       79901  El Paso    TX  El Paso    El Paso      7998
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01    42600.0
#  1996-05-01 1996-05-01    42700.0
#  1996-06-01 1996-06-01    42700.0
#  1996-07-01 1996-07-01    42800.0
#  1996-08-01 1996-08-01    42800.0
#  ...               ...        ...
#  2017-12-01 2017-12-01    64800.0
#  2018-01-01 2018-01-01    64600.0
#  2018-02-01 2018-02-01    65400.0
#  2018-03-01 2018-03-01    67700.0
#  2018-04-01 2018-04-01    69300.0
#
#  [265 rows x 9 columns],
#  79922:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  1996-05-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  1996-06-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  1996-07-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  1996-08-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  2018-01-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  2018-02-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  2018-03-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#  2018-04-01     93131       79922  El Paso    TX  El Paso    El Paso      9651
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01   148500.0
#  1996-05-01 1996-05-01   148500.0
#  1996-06-01 1996-06-01   148500.0
#  1996-07-01 1996-07-01   148500.0
#  1996-08-01 1996-08-01   148500.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   232900.0
#  2018-01-01 2018-01-01   232900.0
#  2018-02-01 2018-02-01   234800.0
#  2018-03-01 2018-03-01   237400.0
#  2018-04-01 2018-04-01   238700.0
#
#  [265 rows x 9 columns],
#  79911:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  1996-04-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  1996-05-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  1996-06-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  1996-07-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  1996-08-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  ...              ...         ...      ...   ...      ...        ...       ...
#  2017-12-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  2018-01-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  2018-02-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  2018-03-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#  2018-04-01     93122       79911  El Paso    TX  El Paso    El Paso     10722
#
#              MonthOrig  MeanValue
#  Month
#  1996-04-01 1996-04-01   130400.0
#  1996-05-01 1996-05-01   130300.0
#  1996-06-01 1996-06-01   130300.0
#  1996-07-01 1996-07-01   130200.0
#  1996-08-01 1996-08-01   130200.0
#  ...               ...        ...
#  2017-12-01 2017-12-01   231600.0
#  2018-01-01 2018-01-01   231800.0
#  2018-02-01 2018-02-01   231700.0
#  2018-03-01 2018-03-01   231800.0
#  2018-04-01 2018-04-01   231900.0
#
#  [265 rows x 9 columns],
#  79836:             RegionID  RegionName     City State    Metro CountyName  SizeRank  \
#  Month
#  2013-07-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2013-08-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2013-09-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2013-10-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2013-11-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2013-12-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-01-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-02-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-03-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-04-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-05-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-06-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-07-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-08-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-09-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-10-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-11-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2014-12-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-01-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-02-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-03-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-04-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-05-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-06-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-07-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-08-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-09-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-10-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-11-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2015-12-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-01-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-02-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-03-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-04-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-05-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-06-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-07-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-08-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-09-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-10-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-11-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2016-12-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-01-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-02-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-03-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-04-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-05-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-06-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-07-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-08-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-09-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-10-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-11-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2017-12-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2018-01-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2018-02-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2018-03-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#  2018-04-01     93097       79836  El Paso    TX  El Paso    El Paso     10282
#
#              MonthOrig  MeanValue
#  Month
#  2013-07-01 2013-07-01    67400.0
#  2013-08-01 2013-08-01    67700.0
#  2013-09-01 2013-09-01    68800.0
#  2013-10-01 2013-10-01    70200.0
#  2013-11-01 2013-11-01    70700.0
#  2013-12-01 2013-12-01    69200.0
#  2014-01-01 2014-01-01    66100.0
#  2014-02-01 2014-02-01    65100.0
#  2014-03-01 2014-03-01    64700.0
#  2014-04-01 2014-04-01    61800.0
#  2014-05-01 2014-05-01    58400.0
#  2014-06-01 2014-06-01    58800.0
#  2014-07-01 2014-07-01    60800.0
#  2014-08-01 2014-08-01    61400.0
#  2014-09-01 2014-09-01    61300.0
#  2014-10-01 2014-10-01    61800.0
#  2014-11-01 2014-11-01    62100.0
#  2014-12-01 2014-12-01    63000.0
#  2015-01-01 2015-01-01    64000.0
#  2015-02-01 2015-02-01    63900.0
#  2015-03-01 2015-03-01    64200.0
#  2015-04-01 2015-04-01    65000.0
#  2015-05-01 2015-05-01    65500.0
#  2015-06-01 2015-06-01    65700.0
#  2015-07-01 2015-07-01    65700.0
#  2015-08-01 2015-08-01    65300.0
#  2015-09-01 2015-09-01    64900.0
#  2015-10-01 2015-10-01    65200.0
#  2015-11-01 2015-11-01    65600.0
#  2015-12-01 2015-12-01    66100.0
#  2016-01-01 2016-01-01    66900.0
#  2016-02-01 2016-02-01    68400.0
#  2016-03-01 2016-03-01    69600.0
#  2016-04-01 2016-04-01    71100.0
#  2016-05-01 2016-05-01    72400.0
#  2016-06-01 2016-06-01    73400.0
#  2016-07-01 2016-07-01    74100.0
#  2016-08-01 2016-08-01    75300.0
#  2016-09-01 2016-09-01    77200.0
#  2016-10-01 2016-10-01    79300.0
#  2016-11-01 2016-11-01    81200.0
#  2016-12-01 2016-12-01    82800.0
#  2017-01-01 2017-01-01    84300.0
#  2017-02-01 2017-02-01    84700.0
#  2017-03-01 2017-03-01    85400.0
#  2017-04-01 2017-04-01    88100.0
#  2017-05-01 2017-05-01    90800.0
#  2017-06-01 2017-06-01    90700.0
#  2017-07-01 2017-07-01    90400.0
#  2017-08-01 2017-08-01    91700.0
#  2017-09-01 2017-09-01    92100.0
#  2017-10-01 2017-10-01    92100.0
#  2017-11-01 2017-11-01    93800.0
#  2017-12-01 2017-12-01    94900.0
#  2018-01-01 2018-01-01    93000.0
#  2018-02-01 2018-02-01    92600.0
#  2018-03-01 2018-03-01    93400.0
#  2018-04-01 2018-04-01    92600.0  }

# %%
#Visualing all the zipcodes
def plot_ts_dict(df_dict,col='MeanValue',zipcodes=[]):
    
    if len(zipcodes)==0:
        zipcodes=list(df_dict.keys())
        
    print(zipcodes)
    
    cutoff = len(zipcodes)//2
    
        
    fig,ax = plt.subplots(figsize=(12,6))
    
    ts_dict = {}
    for i,zc in enumerate(zipcodes):
        if i <cutoff:
            ls='-'
        else:
            ls='--'
            
        ts = df_dict[zc][col].rename(zc)#.loc[zc]
        ts.plot(label=str(zc),ax=ax,ls=ls)
        ts_dict[zc] = ts

    ## CALCULTE MEAN   
    mean = pd.DataFrame(ts_dict).mean(axis=1)
    mean.plot(label='Mean',lw=5,color='black')

    crash = '01-2009'
    ax.axvline(crash, label='Housing Index Drops',color='red',ls=':')

    ax.legend(bbox_to_anchor=(1.04,1), loc="upper left", ncol=2)
    ax.set(title='El Paso - Mean Home Values',
          ylabel='Price($)')

    return fig,ax,ts_dict
fig,ax,tsdict = plot_ts_dict(El_P)
# Out:
# [79936, 79912, 79938, 79924, 79907, 79925, 79915, 79904, 79902, 79934, 79930, 79932, 79905, 79903, 79935, 79901, 79922, 79911, 79836]

# %%
# Importing stats libraries
from statsmodels.tsa.seasonal import seasonal_decompose
from  statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from pandas.plotting import autocorrelation_plot,lag_plot

# %%
# plotting acf and pacf
def plot_acf_pacf(ts, figsize=(10,8),lags=12):
    fig,ax = plt.subplots(nrows=3,figsize=figsize)
    ts.plot(ax=ax[0])
    plot_acf(ts,ax=ax[1],lags=lags)
    plot_pacf(ts, ax=ax[2],lags=lags) 
    plt.tight_layout()
    
    plt.suptitle(f"Zipcode: {ts.name}",y=1.1,fontsize=20)
    
    for a in ax[1:]:
        a.xaxis.set_major_locator(mpl.ticker.MaxNLocator(min_n_ticks=lags, integer=True))
        a.xaxis.grid()

# %%
zips = list(tsdict.keys())
zips
# Out:
# [79936,
#  79912,
#  79938,
#  79924,
#  79907,
#  79925,
#  79915,
#  79904,
#  79902,
#  79934,
#  79930,
#  79932,
#  79905,
#  79903,
#  79935,
#  79901,
#  79922,
#  79911,
#  79836]

# %%
# viewing autocorr and partial corr
import matplotlib as mpl
ts = tsdict[79907]
ts = ts.rename(79907)
plot_acf_pacf(ts)

# %%
# Decomposing 
plt.style.use('seaborn-notebook')
mpl.rcParams['figure.figsize']=(15,8)

decomp = seasonal_decompose(ts)
decomp.plot();
plt.tight_layout()

# %% [markdown]
# # Modeling

# %%
def make_pdq_pdqm(ps=[0,1,3],ds=[0,1,2,3], 
                  qs=[0,1,3],make_seasonal=True,
                  m_values=[12]):
    import itertools
#    ps =range(p_range[0],p_range[1])
#    ds =range(d_range[0],d_range[1])
#    qs =range(q_range[0],q_range[1])
    
    params = {}
    params['pdq'] = list(itertools.product(ps,ds,qs))
    
    if make_seasonal:
        params['PDQm'] = list(itertools.product(ps,ds,qs,m_values))
    return params

# fs.ihelp(ji.get_train_test_split_index,0)
def get_train_test_split_index(ts, TEST_SIZE=0.1,min_test_ts=2):
    import math
    idx_split = math.floor(len(ts.index)*(1-TEST_SIZE))
    
    num_test_ts=len(ts.iloc[idx_split:])
    if num_test_ts<min_test_ts:
        print(f'[!] Warning: using TEST_SIZE={TEST_SIZE} produced {num_test_ts} test timestamps.')
        print("- Overriding TEST_SIZE and using min_test_ts instead.")
        idx_split = len(ts)-min_test_ts
    
    return idx_split


def train_test_split_ts(ts,test_size=0.2,min_test_ts=2):
    idx_split = get_train_test_split_index(ts,TEST_SIZE=test_size,
                                           min_test_ts=min_test_ts)
    ts_train = ts.iloc[:idx_split]
    ts_test = ts.iloc[idx_split:]
    return ts_train, ts_test

def get_now(return_dt = True, return_str=True, show=False):
    import datetime as dt
    import tzlocal as tz
    now=dt.datetime.now(tz=tz.get_localzone())
    str_time =now.strftime('%m/%d/%Y - %I:%M:%S %p')
    if show:
        print(str_time)
    
    output=[]
    if return_dt:
        output.append(now)
        
    if return_str:
        output.append(str_time)
    return output[:]

# %%
#setting up the parameters
params = make_pdq_pdqm()
print(params.keys())
print(params['pdq'][:10])
params['PDQm'][:10]
# Out:
# dict_keys(['pdq', 'PDQm'])
# [(0, 0, 0), (0, 0, 1), (0, 0, 3), (0, 1, 0), (0, 1, 1), (0, 1, 3), (0, 2, 0), (0, 2, 1), (0, 2, 3), (0, 3, 0)]
# [(0, 0, 0, 12),
#  (0, 0, 1, 12),
#  (0, 0, 3, 12),
#  (0, 1, 0, 12),
#  (0, 1, 1, 12),
#  (0, 1, 3, 12),
#  (0, 2, 0, 12),
#  (0, 2, 1, 12),
#  (0, 2, 3, 12),
#  (0, 3, 0, 12)]

# %% [markdown]
# New Grid Search Functions

# %%
# from statsmodels.tsa.statespace.sarimax import SARIMAX
# def grid_search_arima_optional_s(ts_train,pdq=None,pdqm=None,order_dict=None,
#                                  make_seasonal=False, verbose=False, model_kws={}):

#     from tqdm import trange
    
#     if (pdq is None) & (order_dict is not None):
#         pdq= order_dict['pdq']
#     if (pdqm is None) & (order_dict is not None):
#         pdqm= order_dict['PDQm']

#     import tqdm
#     from tqdm import trange

#     start,start_str = get_now(return_dt=True, return_str=True)
#     print(f'[i] STARTING GRID SEARCH @ {start_str}:')
    
    
#     res = [['pdq','PDQM','AIC']]
#     for i in trange((len(pdq))):
#         comb = pdq[i]
        
     
#         ## BRANCH POINT
#         if make_seasonal:
#             for combs in pdqm:
#                 try: 
#                     model = SARIMAX(ts_train, order=comb, 
#                                    seasonal_order =combs,enforce_stationarity=False,
#                                    enforce_invertibility=False,**model_kws)

#                     output= model.fit()
#                     res.append([comb,combs,output.aic])
#                 except:
#                     if verbose:
#                         print(f"[!] Error running ({comb})({combs})")
#                     continue
                    
                    
#         if make_seasonal == False:
#             try: 
#                 model = SARIMAX(ts_train, order=comb, 
#                                 enforce_stationarity=False, 
#                                 enforce_invertibility=False,**model_kws)

#                 output= model.fit()
#                 res.append([comb,'N/A',output.aic])
#             except:
#                 if verbose:
#                     print(f"[!] Error running ({comb})({combs})")
#                     continue
                    
#     end,end_str = get_now(return_dt=True, return_str=True)
#     elapsed = end-start
#     print(f"[i] GRID SEARCH FINISHED AT {end_str}")
#     print(f"\tTotal Time: {elapsed}")

#     try:
#         df_res =fs.list2df(res)
#         return df_res
    
#     except:
#         print('Error converting to df. Returning as list.')
#         return res

# %%
# Grid search
from statsmodels.tsa.statespace.sarimax import SARIMAX
def grid_search (ts_train,pdq=None,pdqm=None,order_dict=None,
                                 make_seasonal=False, verbose=False, model_kws={}):

    from tqdm import trange
    
    if (pdq is None) & (order_dict is not None):
        pdq= order_dict['pdq']
    if (pdqm is None) & (order_dict is not None):
        pdqm= order_dict['PDQm']

    import tqdm
    from tqdm import trange

    start,start_str = get_now(return_dt=True, return_str=True)
    print(f'[i] STARTING GRID SEARCH @ {start_str}:')
    
    
    res = [['pdq','PDQM','AIC']]
    for i in trange((len(pdq))):
        comb = pdq[i]
        
     
        ## BRANCH POINT
        if make_seasonal:
            for combs in pdqm:
                try: 
                    model = SARIMAX(ts_train, order=comb, 
                                   seasonal_order =combs,enforce_stationarity=False,
                                   enforce_invertibility=False,**model_kws)

                    output= model.fit()
                    res.append([comb,combs,output.aic])
                except:
                    if verbose:
                        print(f"[!] Error running ({comb})({combs})")
                    continue
                    
                    
        if make_seasonal == False:
            try: 
                model = SARIMAX(ts_train, order=comb, 
                                enforce_stationarity=False, 
                                enforce_invertibility=False,**model_kws)

                output= model.fit()
                res.append([comb,'N/A',output.aic])
            except:
                if verbose:
                    print(f"[!] Error running ({comb})({combs})")
                    continue
                    
    end,end_str = get_now(return_dt=True, return_str=True)
    elapsed = end-start
    print(f"[i] GRID SEARCH FINISHED AT {end_str}")
    print(f"\tTotal Time: {elapsed}")

    
    res = pd.DataFrame(res[1:], columns= res[0]) 
    res.sort_values('AIC',inplace=True)
    return res

# %% [markdown]
# Testing on Single Zipcode

# %%
#Checkign the shape of ts
ts = tsdict[79902]
ts_train,ts_test = train_test_split_ts(ts,test_size=0.1)

len(ts_train),len(ts_test)
# Out:
# (238, 27)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#res2 = grid_search(ts_train,order_dict=params,make_seasonal=False)#pdq,pdqm)

# %%
res = grid_search(ts_train,order_dict=params,make_seasonal=False)#pdq,pdqm)
res.sort_values('AIC',inplace=True)
res.head()
# Out:
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:21:04 PM:
# 100%|██████████| 36/36 [00:18<00:00,  1.97it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:21:22 PM
# 	Total Time: 0:00:18.336754
#           pdq PDQM          AIC
# 32  (3, 2, 3)  N/A  3584.953585
# 20  (1, 2, 3)  N/A  3594.899793
# 29  (3, 1, 3)  N/A  3597.873615
# 5   (0, 1, 3)  N/A  3600.847958
# 17  (1, 1, 3)  N/A  3601.187577

# %%
res
# Out:
#           pdq PDQM          AIC
# 32  (3, 2, 3)  N/A  3584.953585
# 20  (1, 2, 3)  N/A  3594.899793
# 29  (3, 1, 3)  N/A  3597.873615
# 5   (0, 1, 3)  N/A  3600.847958
# 17  (1, 1, 3)  N/A  3601.187577
# 8   (0, 2, 3)  N/A  3605.698506
# 35  (3, 3, 3)  N/A  3606.989381
# 14  (1, 0, 3)  N/A  3622.086513
# 27  (3, 1, 0)  N/A  3628.674442
# 34  (3, 3, 1)  N/A  3631.360641
# 31  (3, 2, 1)  N/A  3632.736229
# 30  (3, 2, 0)  N/A  3633.156007
# 28  (3, 1, 1)  N/A  3634.442993
# 23  (1, 3, 3)  N/A  3642.621781
# 11  (0, 3, 3)  N/A  3648.706720
# 25  (3, 0, 1)  N/A  3662.222097
# 16  (1, 1, 1)  N/A  3672.766189
# 19  (1, 2, 1)  N/A  3681.113956
# 24  (3, 0, 0)  N/A  3681.746206
# 7   (0, 2, 1)  N/A  3690.542223
# 33  (3, 3, 0)  N/A  3700.957408
# 18  (1, 2, 0)  N/A  3738.908867
# 4   (0, 1, 1)  N/A  3751.566374
# 15  (1, 1, 0)  N/A  3754.448056
# 22  (1, 3, 1)  N/A  3759.312805
# 6   (0, 2, 0)  N/A  3762.104031
# 13  (1, 0, 1)  N/A  3778.513202
# 10  (0, 3, 1)  N/A  3801.544962
# 9   (0, 3, 0)  N/A  3816.627711
# 21  (1, 3, 0)  N/A  3818.570341
# 3   (0, 1, 0)  N/A  3978.750872
# 12  (1, 0, 0)  N/A  3984.390326
# 26  (3, 0, 3)  N/A  4186.899192
# 1   (0, 0, 1)  N/A  6077.051738
# 0   (0, 0, 0)  N/A  6273.626636
# 2   (0, 0, 3)  N/A  7718.296188

# %%
# changing from list to dataframe
#res = pd.DataFrame(res[1:], columns= res[0])

# %%
res.sort_values('AIC',inplace=True)
res.head()
# Out:
#           pdq PDQM          AIC
# 32  (3, 2, 3)  N/A  3584.953585
# 20  (1, 2, 3)  N/A  3594.899793
# 29  (3, 1, 3)  N/A  3597.873615
# 5   (0, 1, 3)  N/A  3600.847958
# 17  (1, 1, 3)  N/A  3601.187577

# %%
# Getting the best params
best_params =  dict(order=res.iloc[0].loc['pdq'])
best_params
# Out:
# {'order': (3, 2, 3)}

# %%
#getting model summary
model_output = SARIMAX(ts_train,**best_params,
                      enforce_invertibility=False,
                      enforce_stationarity=False).fit()
display(model_output.summary())
model_output.plot_diagnostics(figsize=(12,8));
plt.tight_layout()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                  79902   No. Observations:                  238
# Model:               SARIMAX(3, 2, 3)   Log Likelihood               -1785.477
# Date:                Wed, 22 Jan 2020   AIC                           3584.954
# Time:                        22:21:25   BIC                           3609.081
# Sample:                    04-01-1996   HQIC                          3594.684
#                          - 01-01-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0157      0.072      0.219      0.827      -0.125       0.156
# ar.L2          0.1459      0.070      2.073      0.038       0.008       0.284
# ar.L3          0.1551      0.050      3.110      0.002       0.057       0.253
# ma.L1          0.4709      0.370      1.273      0.203      -0.254       1.196
# ma.L2         -0.6901      0.516     -1.337      0.181      -1.702       0.321
# ma.L3         -0.7791      0.276     -2.820      0.005      -1.320      -0.238
# sigma2      2.741e+05   9.35e+04      2.931      0.003    9.08e+04    4.57e+05
# ===================================================================================
# Ljung-Box (Q):                      132.25   Jarque-Bera (JB):                57.02
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              20.71   Skew:                            -0.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#viewing training data
ts_train
# Out:
# Month
# 1996-04-01    101900.0
# 1996-05-01    101700.0
# 1996-06-01    101600.0
# 1996-07-01    101400.0
# 1996-08-01    101300.0
#                 ...
# 2015-09-01    166100.0
# 2015-10-01    165400.0
# 2015-11-01    165500.0
# 2015-12-01    164900.0
# 2016-01-01    162600.0
# Freq: MS, Name: 79902, Length: 238, dtype: float64

# %% [markdown]
# def ROI and model evaluation functions

# %%
# docstring for func( one sentence summary)

# %%
#Evaluating the model
def model_evaluation(ts_true,ts_pred,show=True):
    """pass in ts_true, ts_pred and return res"""
    from sklearn.metrics import mean_squared_error,r2_score

    res= [['Metric','Value']]
    
    res.append(['RMSE', np.sqrt(mean_squared_error(ts_true,ts_pred))])
    
    res.append(['R2',r2_score(ts_true,ts_pred)])
    
    res = pd.DataFrame(res[1:], columns= res[0])
    
    if show:
        display(res)
    return res
    
def expected_roi(investment, final_value):
    """pass in investment and final value"""
    """This function takes in a series of forecasts to predict the return
    on investment spanning the entire forecast."""
    roi = np.round(((final_value - investment) / investment)*100,3)
    return roi

# %%
ts_train.name
# Out:
# 79902

# %%
# def get_model_preds_df(model_output,ts_train,ts_test,start=None,end=None, get_metrics=True):
    
#     if start is None:
#         start=ts_test.index[0]
        
#     if end is None:
#         end=ts_test.index[-1]
        
        
#     # Get predictions starting from 2016 and calculate confidence intervals.
#     prediction = model_output.get_prediction(start=start,end=end, 
#                                              dynamic=True)
    
    
#     preds_df = prediction.conf_int()
#     preds_df['predicted_mean'] = prediction.predicted_mean
#     plot_df = pd.concat([preds_df,ts_train],axis=1)

    
    
#     ## Get roi for preds:
#     roi = expected_roi(preds_df['predicted_mean'].iloc[0],preds_df['predicted_mean'].iloc[-1])
    
#     zc =ts_train.name
    
#     fig, ax = plt.subplots()
#     ts_train.plot(ax=ax,label='Training Data')
#     ts_test.plot(ax=ax,label='Test Data')

    
#     preds_df['predicted_mean'].plot(ax=ax)
#     ax.fill_between(preds_df.index, preds_df[f'lower {zc}'],
#                 preds_df[f'upper {zc}'], color="k", alpha=.15,
#                 label = 'confidence interval')

#     prediction.predicted_mean.plot(ax=ax,label='Predicted')
    
    
#     ax.legend()
#     ax.set(title=f"Predictions for {zc}: ROI = {roi}%")
    
#     fig = ax.get_figure()
    
    
#     plot_df['zipcode']=ts_train.name
#     plt.show()
    
#     if get_metrics:
#         res = model_evaluation(ts_test, preds_df['predicted_mean'])
# #         res['Metric']

#     return preds_df, fig,ax

# %%
def model_predictions(model_output,ts_train,ts_test,start=None,end=None):
    """ This function takes in model_output, training data and test data to return predictions"""
    if start is None:
        start=ts_test.index[0]
        
    if end is None:
        end=ts_test.index[-1] 
        
    prediction = model_output.get_prediction(start=start,end=end, 
                                             dynamic=True)
    
    
    preds_df = prediction.conf_int()
    preds_df['predicted_mean'] = prediction.predicted_mean
    plot_df = pd.concat([preds_df,ts_train],axis=1)
    
    return preds_df

# %%
def plot_pred(ts_train, ts_test, preds_df, start=None, end=None):
    """This function takes in training data, test data and predicted data"""
    
    if start is None:
        start = ts_test.index[0]
    if end is None:
        end =  ts_test.index[-1]
    
    prediction = model_output.get_prediction( start=start,end=end, 
                                             dynamic=True)
    
    zc =ts_train.name 
    
    fig, ax = plt.subplots()
    ts_train.plot(ax=ax,label='Training Data')
    ts_test.plot(ax=ax,label='Test Data')

     
    
    preds_df['predicted_mean'].plot(ax=ax)
    ax.fill_between(preds_df.index, preds_df[f'lower {zc}'],
                preds_df[f'upper {zc}'], color="k", alpha=.15,
                label = 'confidence interval')
    
    prediction.predicted_mean.plot(ax=ax,label='Predicted')

    
    roi = expected_roi(preds_df['predicted_mean'].iloc[0],preds_df['predicted_mean'].iloc[-1])
    
    ax.legend()
    ax.set(title=f"Predictions for {zc}: ROI = {roi}%")
    
    fig = ax.get_figure()
    
    
    preds_df['zipcode']= ts_train.name
    plt.show()
    
    return fig
    

#preds_df,fig,ax = model_predictions(model_output,ts_train,ts_test)
#preds_df

# %%
preds_df = model_predictions(model_output, ts_train, ts_test)
plot_pred(ts_train, ts_test, preds_df)
res = model_evaluation(ts_test, preds_df['predicted_mean'])
# Out:
#   Metric         Value
# 0   RMSE  21720.777844
# 1     R2     -1.798481

# %%
tsdict
# Out:
# {79936: Month
#  1996-04-01     77300.0
#  1996-05-01     77300.0
#  1996-06-01     77300.0
#  1996-07-01     77300.0
#  1996-08-01     77400.0
#                  ...
#  2017-12-01    120300.0
#  2018-01-01    120300.0
#  2018-02-01    120500.0
#  2018-03-01    121000.0
#  2018-04-01    121500.0
#  Freq: MS, Name: 79936, Length: 265, dtype: float64, 79912: Month
#  1996-04-01    119700.0
#  1996-05-01    119700.0
#  1996-06-01    119800.0
#  1996-07-01    119900.0
#  1996-08-01    120000.0
#                  ...
#  2017-12-01    184700.0
#  2018-01-01    184800.0
#  2018-02-01    185900.0
#  2018-03-01    187200.0
#  2018-04-01    188100.0
#  Freq: MS, Name: 79912, Length: 265, dtype: float64, 79938: Month
#  1996-04-01     98400.0
#  1996-05-01     97700.0
#  1996-06-01     97200.0
#  1996-07-01     96700.0
#  1996-08-01     96300.0
#                  ...
#  2017-12-01    143800.0
#  2018-01-01    143700.0
#  2018-02-01    143900.0
#  2018-03-01    144400.0
#  2018-04-01    144600.0
#  Freq: MS, Name: 79938, Length: 265, dtype: float64, 79924: Month
#  1996-04-01    61700.0
#  1996-05-01    61600.0
#  1996-06-01    61500.0
#  1996-07-01    61500.0
#  1996-08-01    61500.0
#                 ...
#  2017-12-01    93600.0
#  2018-01-01    93800.0
#  2018-02-01    94400.0
#  2018-03-01    94900.0
#  2018-04-01    94800.0
#  Freq: MS, Name: 79924, Length: 265, dtype: float64, 79907: Month
#  1996-04-01    58900.0
#  1996-05-01    58800.0
#  1996-06-01    58800.0
#  1996-07-01    58800.0
#  1996-08-01    58700.0
#                 ...
#  2017-12-01    93700.0
#  2018-01-01    93800.0
#  2018-02-01    94000.0
#  2018-03-01    94100.0
#  2018-04-01    93900.0
#  Freq: MS, Name: 79907, Length: 265, dtype: float64, 79925: Month
#  1996-04-01     81600.0
#  1996-05-01     81600.0
#  1996-06-01     81700.0
#  1996-07-01     81800.0
#  1996-08-01     81900.0
#                  ...
#  2017-12-01    126900.0
#  2018-01-01    127400.0
#  2018-02-01    128300.0
#  2018-03-01    129900.0
#  2018-04-01    131200.0
#  Freq: MS, Name: 79925, Length: 265, dtype: float64, 79915: Month
#  1996-04-01    57600.0
#  1996-05-01    57600.0
#  1996-06-01    57700.0
#  1996-07-01    57800.0
#  1996-08-01    57800.0
#                 ...
#  2017-12-01    85600.0
#  2018-01-01    84900.0
#  2018-02-01    84900.0
#  2018-03-01    85500.0
#  2018-04-01    85700.0
#  Freq: MS, Name: 79915, Length: 265, dtype: float64, 79904: Month
#  1996-04-01    60100.0
#  1996-05-01    60100.0
#  1996-06-01    60000.0
#  1996-07-01    60000.0
#  1996-08-01    60000.0
#                 ...
#  2017-12-01    93800.0
#  2018-01-01    94000.0
#  2018-02-01    94200.0
#  2018-03-01    94100.0
#  2018-04-01    93900.0
#  Freq: MS, Name: 79904, Length: 265, dtype: float64, 79902: Month
#  1996-04-01    101900.0
#  1996-05-01    101700.0
#  1996-06-01    101600.0
#  1996-07-01    101400.0
#  1996-08-01    101300.0
#                  ...
#  2017-12-01    189500.0
#  2018-01-01    190100.0
#  2018-02-01    191500.0
#  2018-03-01    192000.0
#  2018-04-01    191200.0
#  Freq: MS, Name: 79902, Length: 265, dtype: float64, 79934: Month
#  1996-04-01     93800.0
#  1996-05-01     93400.0
#  1996-06-01     93100.0
#  1996-07-01     92800.0
#  1996-08-01     92500.0
#                  ...
#  2017-12-01    142700.0
#  2018-01-01    142600.0
#  2018-02-01    142700.0
#  2018-03-01    142700.0
#  2018-04-01    142300.0
#  Freq: MS, Name: 79934, Length: 265, dtype: float64, 79930: Month
#  1996-04-01    58300.0
#  1996-05-01    58400.0
#  1996-06-01    58400.0
#  1996-07-01    58400.0
#  1996-08-01    58400.0
#                 ...
#  2017-12-01    91900.0
#  2018-01-01    92100.0
#  2018-02-01    92400.0
#  2018-03-01    92600.0
#  2018-04-01    92500.0
#  Freq: MS, Name: 79930, Length: 265, dtype: float64, 79932: Month
#  1996-04-01    112400.0
#  1996-05-01    112000.0
#  1996-06-01    111700.0
#  1996-07-01    111300.0
#  1996-08-01    111000.0
#                  ...
#  2017-12-01    175100.0
#  2018-01-01    175800.0
#  2018-02-01    176100.0
#  2018-03-01    176100.0
#  2018-04-01    176000.0
#  Freq: MS, Name: 79932, Length: 265, dtype: float64, 79905: Month
#  1996-04-01    54400.0
#  1996-05-01    54200.0
#  1996-06-01    54100.0
#  1996-07-01    54000.0
#  1996-08-01    53900.0
#                 ...
#  2017-12-01    78300.0
#  2018-01-01    77600.0
#  2018-02-01    77400.0
#  2018-03-01    77800.0
#  2018-04-01    78000.0
#  Freq: MS, Name: 79905, Length: 265, dtype: float64, 79903: Month
#  1996-04-01    58600.0
#  1996-05-01    58500.0
#  1996-06-01    58500.0
#  1996-07-01    58500.0
#  1996-08-01    58600.0
#                 ...
#  2017-12-01    93700.0
#  2018-01-01    93800.0
#  2018-02-01    94400.0
#  2018-03-01    95200.0
#  2018-04-01    95600.0
#  Freq: MS, Name: 79903, Length: 265, dtype: float64, 79935: Month
#  1996-04-01     90700.0
#  1996-05-01     90600.0
#  1996-06-01     90600.0
#  1996-07-01     90600.0
#  1996-08-01     90700.0
#                  ...
#  2017-12-01    141500.0
#  2018-01-01    141100.0
#  2018-02-01    141100.0
#  2018-03-01    141700.0
#  2018-04-01    142400.0
#  Freq: MS, Name: 79935, Length: 265, dtype: float64, 79901: Month
#  1996-04-01    42600.0
#  1996-05-01    42700.0
#  1996-06-01    42700.0
#  1996-07-01    42800.0
#  1996-08-01    42800.0
#                 ...
#  2017-12-01    64800.0
#  2018-01-01    64600.0
#  2018-02-01    65400.0
#  2018-03-01    67700.0
#  2018-04-01    69300.0
#  Freq: MS, Name: 79901, Length: 265, dtype: float64, 79922: Month
#  1996-04-01    148500.0
#  1996-05-01    148500.0
#  1996-06-01    148500.0
#  1996-07-01    148500.0
#  1996-08-01    148500.0
#                  ...
#  2017-12-01    232900.0
#  2018-01-01    232900.0
#  2018-02-01    234800.0
#  2018-03-01    237400.0
#  2018-04-01    238700.0
#  Freq: MS, Name: 79922, Length: 265, dtype: float64, 79911: Month
#  1996-04-01    130400.0
#  1996-05-01    130300.0
#  1996-06-01    130300.0
#  1996-07-01    130200.0
#  1996-08-01    130200.0
#                  ...
#  2017-12-01    231600.0
#  2018-01-01    231800.0
#  2018-02-01    231700.0
#  2018-03-01    231800.0
#  2018-04-01    231900.0
#  Freq: MS, Name: 79911, Length: 265, dtype: float64, 79836: Month
#  2013-07-01    67400.0
#  2013-08-01    67700.0
#  2013-09-01    68800.0
#  2013-10-01    70200.0
#  2013-11-01    70700.0
#  2013-12-01    69200.0
#  2014-01-01    66100.0
#  2014-02-01    65100.0
#  2014-03-01    64700.0
#  2014-04-01    61800.0
#  2014-05-01    58400.0
#  2014-06-01    58800.0
#  2014-07-01    60800.0
#  2014-08-01    61400.0
#  2014-09-01    61300.0
#  2014-10-01    61800.0
#  2014-11-01    62100.0
#  2014-12-01    63000.0
#  2015-01-01    64000.0
#  2015-02-01    63900.0
#  2015-03-01    64200.0
#  2015-04-01    65000.0
#  2015-05-01    65500.0
#  2015-06-01    65700.0
#  2015-07-01    65700.0
#  2015-08-01    65300.0
#  2015-09-01    64900.0
#  2015-10-01    65200.0
#  2015-11-01    65600.0
#  2015-12-01    66100.0
#  2016-01-01    66900.0
#  2016-02-01    68400.0
#  2016-03-01    69600.0
#  2016-04-01    71100.0
#  2016-05-01    72400.0
#  2016-06-01    73400.0
#  2016-07-01    74100.0
#  2016-08-01    75300.0
#  2016-09-01    77200.0
#  2016-10-01    79300.0
#  2016-11-01    81200.0
#  2016-12-01    82800.0
#  2017-01-01    84300.0
#  2017-02-01    84700.0
#  2017-03-01    85400.0
#  2017-04-01    88100.0
#  2017-05-01    90800.0
#  2017-06-01    90700.0
#  2017-07-01    90400.0
#  2017-08-01    91700.0
#  2017-09-01    92100.0
#  2017-10-01    92100.0
#  2017-11-01    93800.0
#  2017-12-01    94900.0
#  2018-01-01    93000.0
#  2018-02-01    92600.0
#  2018-03-01    93400.0
#  2018-04-01    92600.0
#  Freq: MS, Name: 79836, dtype: float64}

# %% [markdown]
# # Meta grid search

# %%
#fig,ax,tsdict = plot_ts_dict(El_P)

# %%
print(ts.index[0])
ts.index[0]+ pd.to_timedelta(1,'MS')
end=ts.index[0]+ pd.to_timedelta(1,'MS')
pd.to_datetime(end)
# Out:
# 1996-04-01 00:00:00
# Timestamp('1996-04-01 00:00:00.001000', freq='MS')

# %%
params = make_pdq_pdqm()

ts_resdict = {}
for zc,ts in tsdict.items():
    print('\n')
    print('---'*30)
    print('---'*30)
    print(f'ZIPCODE: {zc}')
    ## Train test split
    ts_train,ts_test = train_test_split_ts(ts,test_size=0.1)
    

    ## Grid search
    res = grid_search(ts_train,order_dict=params,make_seasonal=False)#pdq,pdqm)
    #res = pd.DataFrame(res[1:], columns= res[0])
    res.sort_values('AIC',inplace=True)
    best_params =  dict(order=res.iloc[0].loc['pdq'])
    
    ts_resdict[zc]={}
    ts_resdict[zc]['res']=res
    ts_resdict[zc]['best_params'] = best_params
    print('Best params: ',best_params)
    

    ## Using best params
    model_output = SARIMAX(ts_train,**best_params,
                      enforce_invertibility=False,
                      enforce_stationarity=False).fit()
    ts_resdict[zc]['model'] = model_output
    
    preds_df = model_predictions(model_output, ts_train, ts_test)
    plot_pred(ts_train, ts_test, preds_df)
    ts_resdict[zc]['preds_df'] = preds_df
# Out:
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79936
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:21:31 PM:
# 100%|██████████| 36/36 [00:17<00:00,  2.01it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:21:49 PM
# 	Total Time: 0:00:17.949744
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79912
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:21:52 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.83it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:22:11 PM
# 	Total Time: 0:00:19.635736
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79938
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:22:13 PM:
# 100%|██████████| 36/36 [00:16<00:00,  2.25it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:22:30 PM
# 	Total Time: 0:00:16.023784
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79924
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:22:33 PM:
# 100%|██████████| 36/36 [00:18<00:00,  1.99it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:22:51 PM
# 	Total Time: 0:00:18.106757
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79907
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:22:55 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.76it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:23:16 PM
# 	Total Time: 0:00:20.484710
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79925
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:23:18 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.84it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:23:38 PM
# 	Total Time: 0:00:19.616722
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79915
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:23:41 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.87it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:24:00 PM
# 	Total Time: 0:00:19.260745
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79904
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:24:02 PM:
# 100%|██████████| 36/36 [00:21<00:00,  1.71it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:24:23 PM
# 	Total Time: 0:00:21.129718
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79902
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:24:27 PM:
# 100%|██████████| 36/36 [00:18<00:00,  1.99it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:24:45 PM
# 	Total Time: 0:00:18.104761
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79934
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:24:48 PM:
# 100%|██████████| 36/36 [00:13<00:00,  2.73it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:25:02 PM
# 	Total Time: 0:00:13.215821
# Best params:  {'order': (1, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79930
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:25:04 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.86it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:25:24 PM
# 	Total Time: 0:00:19.340741
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79932
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:25:26 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.89it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:25:45 PM
# 	Total Time: 0:00:19.078731
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79905
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:25:49 PM:
# 100%|██████████| 36/36 [00:21<00:00,  1.68it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:26:10 PM
# 	Total Time: 0:00:21.467692
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79903
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:26:12 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.83it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:26:32 PM
# 	Total Time: 0:00:19.671739
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79935
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:26:35 PM:
# 100%|██████████| 36/36 [00:16<00:00,  2.15it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:26:52 PM
# 	Total Time: 0:00:16.727500
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79901
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:26:55 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.74it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:27:15 PM
# 	Total Time: 0:00:20.664724
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79922
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:27:21 PM:
# 100%|██████████| 36/36 [00:16<00:00,  2.24it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:27:37 PM
# 	Total Time: 0:00:16.101786
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79911
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:27:40 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.87it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:27:59 PM
# 	Total Time: 0:00:19.285743
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79836
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:28:02 PM:
# 100%|██████████| 36/36 [00:07<00:00,  4.96it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:28:09 PM
# 	Total Time: 0:00:07.262903
# Best params:  {'order': (3, 3, 3)}

# %%
res
# Out:
#           pdq PDQM          AIC
# 35  (3, 3, 3)  N/A   737.800952
# 32  (3, 2, 3)  N/A   741.928303
# 20  (1, 2, 3)  N/A   748.789003
# 8   (0, 2, 3)  N/A   751.226943
# 23  (1, 3, 3)  N/A   759.164270
# 11  (0, 3, 3)  N/A   759.322990
# 5   (0, 1, 3)  N/A   762.754259
# 31  (3, 2, 1)  N/A   763.214920
# 17  (1, 1, 3)  N/A   764.465832
# 34  (3, 3, 1)  N/A   764.882540
# 33  (3, 3, 0)  N/A   765.052196
# 30  (3, 2, 0)  N/A   767.200856
# 29  (3, 1, 3)  N/A   776.050747
# 27  (3, 1, 0)  N/A   781.593053
# 26  (3, 0, 3)  N/A   782.830811
# 28  (3, 1, 1)  N/A   783.109093
# 14  (1, 0, 3)  N/A   788.328481
# 19  (1, 2, 1)  N/A   801.647599
# 16  (1, 1, 1)  N/A   805.533098
# 10  (0, 3, 1)  N/A   807.042519
# 25  (3, 0, 1)  N/A   807.672380
# 22  (1, 3, 1)  N/A   807.918208
# 7   (0, 2, 1)  N/A   808.247879
# 4   (0, 1, 1)  N/A   810.325225
# 24  (3, 0, 0)  N/A   816.959060
# 13  (1, 0, 1)  N/A   823.150154
# 6   (0, 2, 0)  N/A   827.996945
# 18  (1, 2, 0)  N/A   829.697042
# 15  (1, 1, 0)  N/A   837.092003
# 9   (0, 3, 0)  N/A   841.581257
# 21  (1, 3, 0)  N/A   843.242340
# 3   (0, 1, 0)  N/A   863.925252
# 12  (1, 0, 0)  N/A   873.513494
# 1   (0, 0, 1)  N/A  1229.643290
# 0   (0, 0, 0)  N/A  1288.068690
# 2   (0, 0, 3)  N/A  1500.928640

# %% [markdown]
# # Step 6: Interpreting Results

# %%
params = make_pdq_pdqm()

ts_resdict = {}
for zc,ts in tsdict.items():
    print('\n')
    print('---'*30)
    print('---'*30)
    print(f'ZIPCODE: {zc}')
    ## Train test split
    ts_train,ts_test = train_test_split_ts(ts,test_size=0.1)
    

    ## Grid search
    res = grid_search (ts_train,order_dict=params,make_seasonal=False)#pdq,pdqm)
    #res = pd.DataFrame(res[1:], columns= res[0])
    res.sort_values('AIC',inplace=True)
    best_params =  dict(order=res.iloc[0].loc['pdq'])
    
    ts_resdict[zc]={}
    ts_resdict[zc]['res']=res
    ts_resdict[zc]['best_params'] = best_params
    print('Best params: ',best_params)
    

    ## Using best params
    model_output = SARIMAX(ts,**best_params,
                      enforce_invertibility=False,
                      enforce_stationarity=False).fit()
    ts_resdict[zc]['model'] = model_output
    
    preds_df = model_predictions(model_output,ts_train,ts_test,
                                         start=ts.index[-1],end=ts.index.shift(12)[-1], get_metrics=False)#+ pd.to_timedelta(1,'MS'))
    plot_pred(ts_train, ts_test, preds_df)
    ts_resdict[zc]['preds_df'] = preds_df
# Out:
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79936
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:28:11 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.79it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:28:32 PM
# 	Total Time: 0:00:20.178338
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79912
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:28:35 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.73it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:28:56 PM
# 	Total Time: 0:00:20.865911
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79938
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:28:59 PM:
# 100%|██████████| 36/36 [00:16<00:00,  2.17it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:29:15 PM
# 	Total Time: 0:00:16.629295
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79924
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:29:19 PM:
# 100%|██████████| 36/36 [00:17<00:00,  2.01it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:29:37 PM
# 	Total Time: 0:00:17.936759
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79907
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:29:42 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.78it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:30:02 PM
# 	Total Time: 0:00:20.273730
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79925
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:30:04 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.83it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:30:24 PM
# 	Total Time: 0:00:19.643734
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79915
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:30:27 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.81it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:30:47 PM
# 	Total Time: 0:00:19.906775
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79904
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:30:49 PM:
# 100%|██████████| 36/36 [00:20<00:00,  1.72it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:31:10 PM
# 	Total Time: 0:00:20.907715
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79902
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:31:14 PM:
# 100%|██████████| 36/36 [00:18<00:00,  1.98it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:31:32 PM
# 	Total Time: 0:00:18.152734
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79934
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:31:36 PM:
# 100%|██████████| 36/36 [00:13<00:00,  2.67it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:31:49 PM
# 	Total Time: 0:00:13.506393
# Best params:  {'order': (1, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79930
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:31:52 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.88it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:32:12 PM
# 	Total Time: 0:00:19.201746
# Best params:  {'order': (1, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79932
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:32:14 PM:
# 100%|██████████| 36/36 [00:18<00:00,  1.94it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:32:33 PM
# 	Total Time: 0:00:18.551731
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79905
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:32:37 PM:
# 100%|██████████| 36/36 [00:21<00:00,  1.71it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:32:58 PM
# 	Total Time: 0:00:21.043735
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79903
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:33:01 PM:
# 100%|██████████| 36/36 [00:19<00:00,  1.89it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:33:20 PM
# 	Total Time: 0:00:19.102744
# Best params:  {'order': (3, 1, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79935
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:33:22 PM:
# 100%|██████████| 36/36 [00:16<00:00,  2.15it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:33:39 PM
# 	Total Time: 0:00:16.733755
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79901
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:33:43 PM:
# 100%|██████████| 36/36 [00:21<00:00,  1.66it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:34:05 PM
# 	Total Time: 0:00:21.644847
# Best params:  {'order': (3, 3, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79922
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:34:08 PM:
# 100%|██████████| 36/36 [00:17<00:00,  2.09it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:34:25 PM
# 	Total Time: 0:00:17.221768
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79911
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:34:29 PM:
# 100%|██████████| 36/36 [00:21<00:00,  1.69it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:34:50 PM
# 	Total Time: 0:00:21.292748
# Best params:  {'order': (3, 2, 3)}
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# ZIPCODE: 79836
# [i] STARTING GRID SEARCH @ 01/22/2020 - 10:34:54 PM:
# 100%|██████████| 36/36 [00:07<00:00,  4.54it/s]
# [i] GRID SEARCH FINISHED AT 01/22/2020 - 10:35:02 PM
# 	Total Time: 0:00:07.951893
# Best params:  {'order': (3, 3, 3)}

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From our model, we  came up with these 5 top zip codes with the highest ROI

# %% [markdown]
# # Best 5 zip codes to invest in the city of El paso
#
# 79901 = 21.691%
# 79925 = 15.123%
# 79936 = 5.138%
# 79924 = 5.064%
# 79912 = 4.719%
